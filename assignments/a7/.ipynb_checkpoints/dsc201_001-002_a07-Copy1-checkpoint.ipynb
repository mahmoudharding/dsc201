# %% [markdown]
# # Assignment 07
#
# ## Due: See Date in Moodle
#
# In this assignment you will use intermediate and advanced features in R.
#
# To receive a **full credit** for this assignment, you must complete **all** questions.
#
# ## This Week's Assignment
#
# In this week's assignment, you will perform data wrangling. This includes, but is not limited to the following:
#
# - converting strings to numbers
#
# - adding a new column to a dataframe
#
# ### Notes
#
# - Adhere to good programming practices, utilizing descriptive variable names, appropriate spacing for readability, and adding comments to your code.
#
# - Ensure written responses maintain correct spelling, complete sentences, and proper grammar.
#
# **Name:**
#
# **Section:**
#
# **Date:**
#
# In this notebook we will be working with a slightly modified version of the skyscraper data that your class collected. The dataset can be accessed [**here**](https://docs.google.com/spreadsheets/d/1W0uRGIU43sMvQ1pANUtlSkFKeY_TMl9d3QZyegEhxOo/edit#gid=1105865786).
#
#
# Let's get started!

# %%
ss <- read.csv('data/skyscrapers_world.csv')
head(ss)
# Out:
#   X name                     city          country      status.started
# 1 1 Burj Khalifa             Dubai         UAE          2009
# 2 2 Shanghai Tower           Shanghai      China        2008
# 3 3 Makkah Royal Clock Tower Mecca         Saudi Arabia 2002
# 4 4 Ping An Finance Center   Shenzhen      China        2010
# 5 5 Lotte World Tower        Seoul         South Korea  2012
# 6 6 One World Trade Center   New York City New York     2006
#   status.completed height.in.meters height             floors material
# 1 2010             2,722            2,722 ft           163    steel/concrete
# 2 2014             2073             2073 ft            128    composite
# 3 2012             601              601 m / 1972 ft    120    steel/concrete
# 4 2017             599.1            599.1 m / 1965 ft  115    composite
# 5 2017             554.5            554.5 m / 1,819 ft 123    composite
# 6 2014             541.3            541.3 m / 1,776 ft 94     composite
#   function.
# 1 variety
# 2 Misc, Cultural Monument
# 3 Clock/Retail/Hotel/Residential
# 4 Office/Retail/Hotel
# 5 hotel / residential / office / retail
# 6 office

# %% [markdown]
# ## Data Wrangling and Cleaning in R
#
# ### `dplyr`
#
# `dplyr` is an R package from the `tidyverse` that is designed for data manipulation and transformation. Key functions in `dplyr` for performing data moves include `filter()`, `select()`, `mutate()`, `arrange()`, and the combination of `group_by()` with `summarize()`.
#
# **Question 1.** Load the `dplyr` package.

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Let's replicate the data cleaning and wranlging we performed in Python using R instead.
#
# **Example 1.** Drop the `X` column.

# %%
ss <- ss %>% 
        select(-'X')

colnames(ss)
# Out:
#  [1] "name"             "city"             "country"          "status.started"
#  [5] "status.completed" "height.in.meters" "height"           "floors"
#  [9] "material"         "function."

# %% [markdown]
# **Example 2.** Rename the `status.completed`, `status.started`, and `height in meters` columns to `snake_case` format.

# %%
ss <- ss %>% 
        rename(year_completed = 'status.completed',
               year_started = 'status.started',
               height_meters = 'height.in.meters'
)

colnames(ss)
# Out:
#  [1] "name"           "city"           "country"        "year_started"
#  [5] "year_completed" "height_meters"  "height"         "floors"
#  [9] "material"       "function."

# %% [markdown]
# **Example 3.** Standardize the `height` column by keeping only values in meters and converting the data type from character to numeric.
#
#
# **Notes:**
#
# ```
# gsub(pattern, replacement, x)
# ```
# - The `gsub()` function in R is used for pattern replacement within character strings. It searches for a specified pattern or regular expression in a string and replaces it with a given value.
#
# - Here, it searches for commas (`","`) in the `height_meters` column and replaces them with an empty string (`"`").
#
# ```
# as.numeric(...)
# ```
#
# - The `as.numeric()` function converts a character string into a numeric data type.
#
# - After `gsub()` removes the commas, the cleaned value (which is still a string) is converted into a numeric format.

# %%
ss <- ss %>%
  mutate(clean_height_meters = as.numeric(gsub(",", "", height_meters)))

# %%
ss$clean_height_meters
# Out:
#   [1] 2722.0 2073.0  601.0  599.1  554.5  541.3  530.0  530.4  528.0  508.0
#  [11]  492.0  484.0  472.4  462.0  461.2  452.1  459.1  459.1  450.0  450.0
#  [21]  445.5  443.1  442.3  441.8  438.6  435.0  427.0  425.7  425.0  423.2
#  [31]  420.5  429.6  413.4  412.6  412.0  411.6 1321.0 1316.0  392.5  392.4
#  [41]  390.2  388.1  387.1  385.0  384.0  283.2  381.3  381.2 1250.0 1248.0
#  [51]  376.0  375.5 1227.0 1480.0 1214.0  368.0  368.9  368.1  367.4  365.8
#  [61]  362.9  360.0  358.9  356.3  355.4  355.4  354.6  354.6  354.5  354.3
#  [71]  352.0   35.6  350.0  349.0  378.0  343.0 1136.0 1135.0 1132.0 1128.0
#  [81]  342.5  342.0  341.4  339.1  256.0  249.0  339.1  339.0  339.0  339.0
#  [91]  338.9  338.8  338.0  338.0  337.7  336.9  336.0  335.3  335.1  335.0
# [101]  335.0  333.3

# %% [markdown]
# **Example 4.** Identify non-numeric values in the `floors` column and convert them to numeric values.

# %%
ss[is.na(as.numeric(ss$floors)), ]
# Out:
# Warning message in `[.data.frame`(ss, is.na(as.numeric(ss$floors)), ):
# “NAs introduced by coercion”
#    name                  city          country                 year_started
# 49 Empire State Building New York City United Sates of America 1930
# 62 Almas Tower           Dubai         United Arab Emirates    2005
#    year_completed height_meters height
# 49 1931           1,250         1,250 feet / 380 meters
# 62 2008           360           360 m or 1,181 ft
#    floors                                  material function.
# 49 103 floors                              steel    tourist, office
# 62 73 (68 Above Ground and 5 Below Ground) concrete Office
#    clean_height_meters
# 49 1250
# 62  360

# %%
ss$floors[49] <- 103
ss$floors[62] <- 73
# Out:
#   [1] "163" "128" "120" "115" "123" "94"  "111" "97"  "109" "101" "101" "108"
#  [13] "98"  "87"  "81"  "95"  "88"  "88"  "95"  "66"  "96"  "88"  "110" "98"
#  [25] "111" "84"  "62"  "85"  "101" "100" "88"  "88"  "101" "80"  "88"  "101"
#  [37] "87"  "79"  "68"  "88"  "80"  "80"  "73"  "72"  "69"  "80"  "82"  "88"
#  [49] "103" "91"  "73"  "70"  "79"  "97"  "86"  "72"  "73"  "77"  "72"  "72"
#  [61] "101" "73"  "65"  "75"  "82"  "82"  "54"  "79"  "74"  "85"  "86"  "68"
#  [73] "80"  "61"  "85"  "74"  "88"  "73"  "79"  "100" "74"  "65"  "71"  "85"
#  [85] "56"  "50"  "59"  "69"  "68"  "60"  "72"  "75"  "75"  "65"  "69"  "75"
#  [97] "78"  "62"  "88"  "74"  "74"  "60"

# %%
ss$floors <- as.numeric(ss$floors)
ss$floors
# Out:
#   [1] 163 128 120 115 123  94 111  97 109 101 101 108  98  87  81  95  88  88
#  [19]  95  66  96  88 110  98 111  84  62  85 101 100  88  88 101  80  88 101
#  [37]  87  79  68  88  80  80  73  72  69  80  82  88 103  91  73  70  79  97
#  [55]  86  72  73  77  72  72 101  73  65  75  82  82  54  79  74  85  86  68
#  [73]  80  61  85  74  88  73  79 100  74  65  71  85  56  50  59  69  68  60
#  [91]  72  75  75  65  69  75  78  62  88  74  74  60

# %% [markdown]
# **Question 2.** Filter the `data.frame` to include only rows where the `country` column matches one of the values in `uae`. Then, extract the row indices of these filtered rows.

# %%
uae <- c("United Arab Emirates", "United Arab Emirates (UAE)", "Dubai", "UAE")

mask <- ss$country %in% uae

rows <- which(mask)

rows
# Out:
#  [1]  1 29 33 40 48 50 56 62 64 65 66 67 71 82 97 99

# %% [markdown]
# **Note:** The `which()` function in R returns the indices of TRUE values in a logical vector. It is commonly used to find the positions of elements that satisfy a certain condition.

# %%
for (i in rows) {
  previous_label <- ss[i, "country"]
  ss[i, "country"] <- "UAE"
  cat(sprintf("Row index: %-5d Previous label: %-30s New label: %-20s\n",
              i, previous_label, ss[i, "country"]))
}
# Out:
# Row index: 1     Previous label: UAE                            New label: UAE
# Row index: 29    Previous label: United Arab Emirates           New label: UAE
# Row index: 33    Previous label: United Arab Emirates           New label: UAE
# Row index: 40    Previous label: Dubai                          New label: UAE
# Row index: 48    Previous label: United Arab Emirates           New label: UAE
# Row index: 50    Previous label: United Arab Emirates           New label: UAE
# Row index: 56    Previous label: United Arab Emirates           New label: UAE
# Row index: 62    Previous label: United Arab Emirates           New label: UAE
# Row index: 64    Previous label: United Arab Emirates           New label: UAE
# Row index: 65    Previous label: United Arab Emirates (UAE)     New label: UAE
# Row index: 66    Previous label: United Arab Emirates (UAE)     New label: UAE
# Row index: 67    Previous label: United Arab Emirates           New label: UAE
# Row index: 71    Previous label: United Arab Emirates           New label: UAE
# Row index: 82    Previous label: United Arab Emirates           New label: UAE
# Row index: 97    Previous label: United Arab Emirates           New label: UAE
# Row index: 99    Previous label: United Arab Emirates           New label: UAE

# %% [markdown]
# **Note:** The `sprintf()` function in R is used for formatted string output, similar to Python’s `f-string` or `format()` method. It allows you to embed values into strings with specific formatting, such as fixed decimal places, padding, and alignment.

# %% [markdown]
# **Example 5.** Change the mislabeld value for China.

# %%
ss$country[39]
# Out:
# [1] "Shenzhen"

# %%
ss$country[39] <- 'China'
ss$country[39]
# Out:
# [1] "China"

# %% [markdown]
# ## Visualization in R
#
# `ggplot2` is a data visualization library in R. It is part of the `tidyverse` and follows the **grammar of graphics**, which allows users to build plots layer by layer.
#
# `ggplot2` uses the following structure:
#
# ```
# ggplot(data, aes(x = ..., y = ...)) +
#   geom_xxx() +
#   additional_layers
# ```
#
# - `ggplot(data, aes(x, y))`: Calls the `ggplot()` function to initialize the plot with data and aesthetics `(aes())`
#
# - `geom_...()`: Specifies the type of plot (e.g., `geom_point()` for scatter plots)
#
# - `+ additional_layers`: Can include labels, themes, colors, facets, etc.
#
# Load the `ggplot2` library.

# %%
library(ggplot2)

# %%
# Set default plot size for all plots.
# This ensures all plots have consistent sizing.
options(repr.plot.width = 12, repr.plot.height = 8)

# %% [markdown]
# ### Bar Chart
#
# Let's look a a summary of the material column labels.
#
# **Example 6.** Create a table for the frequency counts in the `material` column.

# %%
tbl <- table(ss$material)
tbl
# Out:
#      composite       concrete          steel steel/concrete
#             60             29              8              5

# %% [markdown]
# To create a plot in `ggplot2`, we first initialize a `ggplot` object with data and aesthetic mappings. Then, we add layers such as geoms (`geom_bar()`), labels, and themes to build the complete visualization.
#
# **Question 4.** Create a bar chart to visualiza the distriubtion of the materials used in the `ss` dataframe.
#
# - First create the `ggplot` object.

# %%
g <- ggplot(data = ss, aes(x = material))

# %%
g
# Out:
# plot without title

# %% [markdown]
# Then add the layers to the `ggplot` object `g`.

# %%
g + geom_bar()
# Out:
# plot without title

# %% [markdown]
# After that you can customize the layers (in this case `geom_bar()`).

# %%
g + geom_bar(fill = 'lightblue')
# Out:
# plot without title

# %% [markdown]
# You can also add a labels layer and change the theme.

# %%
g + geom_bar(fill = 'lightblue', color = 'black') +
  labs(title = 'Distribution of Materials', x = 'Category', y = 'Count') +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# You can also change the bin labels.

# %%
g + geom_bar(fill = 'lightblue', color = 'black') +
  labs(title = 'Distribution of Materials', x = NULL, y = 'Count') +
  scale_x_discrete(labels = c('composite' = 'Composite', 
                              'concrete' = 'Concrete', 
                              'steel' = 'Steel', 
                              'steel/concrete' = 'Steel/Concrete')
                  ) +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# The process for creating different types of plots in `ggplot2` follows a similar structure:
#
# 1. Initialize the `ggplot` object: Define the dataset and aesthetics using `ggplot(data, aes(...))`.
#
# 1. Add a geometric layer (`geom_...()`): Choose the appropriate geom for visualization (e.g., `geom_point()`, `geom_bar()`, `geom_line()`).
#
# 1. Customize the geom layer: Modify colors, sizes, transparency, or other visual properties.
#
# 1. Add labels and annotations:Use `labs()` to specify the title, axis labels, and captions.
#
# 1. Add additional layers: Include facets, guides, or other modifications.
#
# 1. Apply a theme: Choose a built-in theme (e.g., `theme_minimal()`, `theme_classic()`) or customize elements with `theme()`.
#
#
# ### Histogram
#
# **Question 5:** Create a histogram to visualizae the distribution of the `floors`.

# %%
g <- ggplot(data = ss, aes(x = floors))
g + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
g + geom_histogram(bins = 15, fill = 'lightblue', color = 'white') +
  labs(title = 'Distribution of Floors', x = NULL, y = 'Frequency') +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **Question 6.** Examine the histogram of floor counts in the dataset. What trends do you observe, and what insights can be drawn from the distribution?
#
# In particular, explore:
#
# - How the distribution of floors varies across the dataset.
#
# - Potential factors that may influence floor counts (e.g., building type, region, or year built).
#
# - Whether any outliers or unusual patterns exist in the data.

# %% [markdown]
# _TYPE YOUR ANSWER HERE REPLACING THIS TEXT_

# %% [markdown]
# #### Facet
#
# A facet in `ggplot2` is a way to split a plot into multiple subplots based on the values of one or more categorical variables. Each subplot (facet) shows a subset of the data, making it easier to compare distributions or trends across different groups.
#
# **Example 7.** Create a faceted histogram to visualize the distribution of floors across different material types to compare of floor counts by material category.

# %%
g + geom_histogram(bins = 15, fill = 'lightblue', color = 'white') +
  facet_wrap(~ material) +
  labs(title = 'Distribution of Floors', x = NULL, y = 'Frequency') +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# - `facet_wrap(~ material)`: Creates separate plots (facets) for each unique value in the material column.
#
# - Each facet shares the **same axes**, but plots data independently for each category.

# %% [markdown]
# **Question 7:** Examine the faceted histogram of floor counts across material types. What trends do you observe, and what insights can be drawn from the distributions?
#
# In particular, explore:
#
# - How the distribution of floors varies across different material types.
#
# - Potential factors that may influence floor counts (e.g., building type, region, or year built).
#
# - Whether any outliers or unusual patterns exist within specific material categories.

# %% [markdown]
# _TYPE YOUR ANSWER HERE REPLACING THIS TEXT_

# %% [markdown]
# ### Box Plots
#
# A box plot can also be used to visualize the distribution of floors across different material types to compare of heights by material category.
#
# **Example 8.** Create a box plot to compare the distribution of the numerical variable fare grouped by passenger ticket class status.

# %%
g <- ggplot(data = ss, aes(x = material, y = clean_height_meters))

# %%
g + geom_boxplot(fill = 'lightblue', color = 'black')
# Out:
# plot without title

# %% [markdown]
# ### Scatter Plot
#
# We can create a scatter plot to visualize the relationship between height and floors.
#
# **Question 8:** Create a scatter plot to visualize the relationship between height and floors.

# %%
g <- ggplot(data = ss, aes(x = clean_height_meters, y = floors))

# %%
g + geom_point(size = 2)
# Out:
# plot without title

# %% [markdown]
# **Question 9:** Examine the scatter plot of height and floors. What trends do you observe, and what insights can be drawn from the relationship between these variables?
#
# In particular, explore:
#
# - How the relationship between height and the number of floors varies.
#
# - Potential factors that may influence this relationship (e.g., building type, region, or construction year).
#
# - Whether any outliers or unusual patterns exist.

# %% [markdown]
# _TYPE YOUR ANSWER HERE REPLACING THIS TEXT_

# %% [markdown]
# **Example 9.** Color the points in the scatter plot based on the material type.

# %%
g <- ggplot(data = ss, aes(x = clean_height_meters, y = floors, color = material))

# %%
g + geom_point()
# Out:
# plot without title

# %% [markdown]
# What do you notice? What do you wonder?

# %% [markdown]
# ### Line Charts
#
# When visualizing time series data, a line chart is typically more effective than a scatter plot because it helps show trends, patterns, and continuity over time.
#
# - Generally speaking a line chart is better for time series data because it:
#
#   - shows trends and patterns over time (e.g., increasing, decreasing, seasonal variations).
#
#   - emphasizes the connection between data points (since time is continuous).
#
#   - helps identify cycles, peaks, and outliers more clearly.
#
#
# - Sometimes a scatter plot might be used instead:
#
#     - If the data points are sparse and do not follow a clear trend.
#
#     - When exploring individual time-stamped events rather than continuous trends.

# %%
dat <- ss %>%
         group_by(year_completed) %>%
         summarize(median_height = median(clean_height_meters))
dat
# Out:
#    year_completed                        median_height
# 1  13 November 2012                       355.40
# 2  1931                                  1250.00
# 3  1969                                  1128.00
# 4  1973                                  1136.00
# 5  1974                                   442.30
# 6  1990                                   367.40
# 7  1992                                  1227.00
# 8  1996                                   424.65
# 9  1997                                   378.00
# 10 1998                                  1135.00
# 11 1999                                   429.60
# 12 2000                                   354.60
# 13 2003                                   334.00
# 14 2004                                   508.00
# 15 2006                                   333.30
# 16 2007                                   492.00
# 17 2008                                   304.50
# 18 2009                                   394.50
# 19 2010                                   484.00
# 20 2011                                   382.30
# 21 2012                                   413.40
# 22 2013                                   338.80
# 23 2014                                   461.25
# 24 2015                                   342.00
# 25 2016                                   388.30
# 26 2017                                   452.10
# 27 2018                                   350.70
# 28 2019                                   399.35
# 29 2020                                   362.90
# 30 2021                                   385.00
# 31 2022                                   368.90
# 32 27 February 2013                       355.40
# 33 The building was completed in Q1 2017  368.00

# %%
dat %>% slice(2:31)
# Out:
#    year_completed median_height
# 1  1931           1250.00
# 2  1969           1128.00
# 3  1973           1136.00
# 4  1974            442.30
# 5  1990            367.40
# 6  1992           1227.00
# 7  1996            424.65
# 8  1997            378.00
# 9  1998           1135.00
# 10 1999            429.60
# 11 2000            354.60
# 12 2003            334.00
# 13 2004            508.00
# 14 2006            333.30
# 15 2007            492.00
# 16 2008            304.50
# 17 2009            394.50
# 18 2010            484.00
# 19 2011            382.30
# 20 2012            413.40
# 21 2013            338.80
# 22 2014            461.25
# 23 2015            342.00
# 24 2016            388.30
# 25 2017            452.10
# 26 2018            350.70
# 27 2019            399.35
# 28 2020            362.90
# 29 2021            385.00
# 30 2022            368.90

# %%
dat <- dat %>% slice(2:31)

# %%
dat$year_completed <- as.numeric(dat$year_completed)

# %%
g <- ggplot(data = dat, aes(x = year_completed, y = median_height))

# %%
g + geom_line()
# Out:
# plot without title

# %%
dat <- dat %>% slice(5:31)

# %%
g <- ggplot(data = dat, aes(x = year_completed, y = median_height))

# %%
g + geom_line()
# Out:
# plot without title

# %% [markdown]
# What if we did a scatter plot?

# %%
g <- ggplot(data = ss, aes(x = as.numeric(year_completed), y = clean_height_meters))

# %%
g + geom_point(size = 2)
# Out:
# Warning message in FUN(X[[i]], ...):
# “NAs introduced by coercion”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# **Question 10:** Which plot, the line plot or the scatter plot, is most useful for this data? Explain your choice by describing how it best represents trends or patterns and why it is the most effective visualization.

# %% [markdown]
# _TYPE YOUR ANSWER HERE REPLACING THIS TEXT_

# %% [markdown]
# #### What is a factor in R?
#
# A factor in R is a categorical variable type used to store and manage discrete groups or categories efficiently. Factors are particularly useful when working with grouped data in statistical models and visualizations.
#
# #### Why `factor(material)`?
# cyl (Cylinders) is numeric (4, 6, 8) in mtcars, but we want it to be treated as a category (not continuous).
#
# factor(cyl) converts cyl into a categorical variable, ensuring that:
#
# The x-axis displays distinct categories (4, 6, 8) instead of treating them as continuous values.
#
# The box plots are grouped correctly by category rather than attempting to interpolate along a continuous scale.
